# %%
import pandas as pd
import os

# %%
# Function to clean data and add a new 'Year' column
def clean_and_add_year(file_path, year):
    # Load Data
    column_names = ['Day', "01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]

    start_date = f'{year}-01-01'
    end_date = f'{year}-12-31'
    date_list = pd.date_range(start=start_date, end=end_date, freq='D').tolist()

    weather_data = pd.read_csv(file_path, sep='\t', header=None, names=column_names)
    weather_data = weather_data.drop(weather_data.tail(3).index)
    weather_data = weather_data.melt(id_vars='Day', var_name='Month', value_name='Temperature')
    weather_data.dropna(subset=['Temperature'], inplace=True)
 
    # Convert Date 
    weather_data["Day"] = date_list
    weather_data.drop("Month", axis=1, inplace=True)
    print(weather_data.head())

    # Save the cleaned data to a new CSV file
    cleaned_file_path = file_path.replace('.txt', '_cleaned.csv')
    weather_data.to_csv(cleaned_file_path, index=False)
    print(f'Data cleaned and saved to {cleaned_file_path}')

# %%
# Specify the directory where your CSV files are stored
directory_path = 'C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport'
cleaned_file_path = 'C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport'
# Loop through each CSV file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith('.txt'):
        # Extract the year from the file name (assuming the format is 'a{year}.csv')
        year = int(file_name[7:-4])  # Extracts the year from the file name, excluding '.csv'
        
        # Construct the full file path
        file_path = os.path.join(directory_path, file_name)

        # Call the function to clean and add the 'Year' column
        clean_and_add_year(file_path, year)
# Out:
#          Day  Temperature
# 0 2010-01-01         30.2
# 1 2010-01-02         31.8
# 2 2010-01-03         22.2
# 3 2010-01-04         25.4
# 4 2010-01-05         28.3
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2010_cleaned.csv
#          Day  Temperature
# 0 2011-01-01         33.3
# 1 2011-01-02         25.4
# 2 2011-01-03         21.2
# 3 2011-01-04         21.4
# 4 2011-01-05         23.9
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2011_cleaned.csv
#          Day  Temperature
# 0 2012-01-01         27.6
# 1 2012-01-02         28.5
# 2 2012-01-03         29.0
# 3 2012-01-04         34.1
# 4 2012-01-05         26.1
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2012_cleaned.csv
#          Day  Temperature
# 0 2013-01-01         27.1
# 1 2013-01-02         23.4
# 2 2013-01-03         25.5
# 3 2013-01-04         28.4
# 4 2013-01-05         30.9
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2013_cleaned.csv
#          Day  Temperature
# 0 2014-01-01         28.1
# 1 2014-01-02         36.8
# 2 2014-01-03         28.3
# 3 2014-01-04         26.3
# 4 2014-01-05         29.0
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2014_cleaned.csv
#          Day  Temperature
# 0 2015-01-01         30.7
# 1 2015-01-02         27.5
# 2 2015-01-03         31.4
# 3 2015-01-04         33.8
# 4 2015-01-05         25.8
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2015_cleaned.csv
#          Day  Temperature
# 0 2016-01-01         26.5
# 1 2016-01-02         25.3
# 2 2016-01-03         24.3
# 3 2016-01-04         25.4
# 4 2016-01-05         21.0
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2016_cleaned.csv
#          Day  Temperature
# 0 2017-01-01         28.3
# 1 2017-01-02         28.7
# 2 2017-01-03         23.8
# 3 2017-01-04         24.5
# 4 2017-01-05         27.9
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2017_cleaned.csv
#          Day  Temperature
# 0 2018-01-01         28.3
# 1 2018-01-02         28.7
# 2 2018-01-03         23.8
# 3 2018-01-04         24.5
# 4 2018-01-05         27.9
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2018_cleaned.csv
#          Day  Temperature
# 0 2019-01-01         34.2
# 1 2019-01-02         28.5
# 2 2019-01-03         28.9
# 3 2019-01-04         33.0
# 4 2019-01-05         40.3
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2019_cleaned.csv
#          Day  Temperature
# 0 2020-01-01         26.2
# 1 2020-01-02         26.6
# 2 2020-01-03         30.9
# 3 2020-01-04         43.3
# 4 2020-01-05         24.4
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2020_cleaned.csv
#          Day  Temperature
# 0 2021-01-01         22.6
# 1 2021-01-02         21.3
# 2 2021-01-03         26.0
# 3 2021-01-04         29.3
# 4 2021-01-05         28.3
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2021_cleaned.csv
#          Day  Temperature
# 0 2022-01-01         28.5
# 1 2022-01-02         29.9
# 2 2022-01-03         27.9
# 3 2022-01-04         28.1
# 4 2022-01-05         26.7
# Data cleaned and saved to C:/Users/David/Documents/VWL/Master Toulouse/Semester 2 M1/Applied  Metrics Project/Data/Weather Sydney Airport\weather2022_cleaned.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4f84b05b8c77> in <module>
#      12
#      13         # Call the function to clean and add the 'Year' column
# ---> 14         clean_and_add_year(file_path, year)
#
# <ipython-input-4-a6bda8d8bc8e> in clean_and_add_year(file_path, year)
#      14
#      15     # Convert Date
# ---> 16     weather_data["Day"] = date_list
#      17     weather_data.drop("Month", axis=1, inplace=True)
#      18     print(weather_data.head())
#
# c:\Users\David\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# c:\Users\David\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    4141         ensure homogeneity.
#    4142         """
# -> 4143         value = self._sanitize_column(value)
#    4144
#    4145         if (
#
# c:\Users\David\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4868
#    4869         if is_list_like(value):
# -> 4870             com.require_length_match(value, self.index)
#    4871         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4872
#
# c:\Users\David\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     574     """
#     575     if len(data) != len(index):
# --> 576         raise ValueError(
#     577             "Length of values "
#     578             f"({len(data)}) "
#
# ValueError: Length of values (365) does not match length of index (362)
